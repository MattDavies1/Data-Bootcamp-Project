# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
data_path = os.path.join("Resources", "data_tracker.csv")

data = pd.read_csv(data_path)
data
# Out:
#                                        Data File  \
# 0                         canada_polpulation.csv
# 1                        heavy_drinking_data.csv
# 2                   ontario_impaired_driving.csv
# 3                   sales_data_value_alcohol.csv
# 4                education_participation_age.csv
# 5                   cannabis_usage_1961_2018.csv
# 6                        alcohol_sales_89_18.csv
# 7              Toronto_06_19_Alcohol_Related.csv
# 8  Cannabis_Harms_Snapshot_Data_2003_2018 2.xlsx
# 9                Alcohol_AH_Inequities_Data.xlsx
#
#                                             Contents  Start Date  End Date
# 0           Census population for canada 1961 - 2018        1961      2018
# 1               Canada level drinking from 2015 - 18        2015      2018
# 2         "Prov: ON Impaired Driving from 1998-2019"        1999      2019
# 3              "Canada alcohol sales from 1993-2013"        1993      2013
# 4            "Level of education Canadians recieved"        1995      2019
# 5                          "Canadian cannabis usage"        1961      2018
# 6       "Alcohol sales for each province and Canada"        1989      2018
# 7                 "drunk driving accidents Toronto"         2006      2019
# 8                           "Cannabis related harms"        2003      2018
# 9   "Alcohol attributable hospitalizations in Ont...        2004      2017

# %%
#Estalish variables required for formatting Gantt

number_files = len(data)
y_ticks = np.arange(1,number_files+1)
files = list(data['Data File'])

# %%
fig, gnt = plt.subplots()

# Format output
gnt.set_title('Data Set Overlap')
gnt.set_xlabel('Year') 
gnt.set_ylabel('Data Set') 
gnt.grid(True)

# Set axes
gnt.set_ylim(0,number_files + 1)
gnt.set_xlim(1960, 2020)

# Set and label ticks on y-axis 
gnt.set_yticks(y_ticks)
gnt.set_yticklabels(files) 

# Create empty variable to track location on graph in for loop
location = 0

# Loop to make Bars for Gantt
for index, row in data.iterrows():
    start = int(row['Start Date'])
    end = int(row['End Date'])
    gnt.broken_barh([(start, end-start)], (location+0.5, 0.9))
    location += 1
