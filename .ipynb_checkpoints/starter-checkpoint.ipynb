# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
data_path = os.path.join('Resources', 'cannabis_usage_1961_2018.csv')
cannabis = pd.read_csv(data_path)

# Clean headers
cannabis.columns = cannabis.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
cannabis
# Out:
#          sum_of_value                          column_labels unnamed:_2  \
# 0          Row Labels  At least once a week (excludes daily)      Daily
# 1   15 years and over                               44032484   29400807
# 2                1971                                 420021     288392
# 3                1972                                 462420     316578
# 4                1973                                 500216     340918
# 5                1974                                 533318     362231
# 6                1975                                 562227     380581
# 7                1976                                 587525     396701
# 8                1977                                 610785     410874
# 9                1978                                 632216     424159
# 10               1979                                 652308     436525
# 11               1980                                 671215     448465
# 12               1981                                 689658     459378
# 13               1982                                 706711     469620
# 14               1983                                 721889     478491
# 15               1984                                 733529     485262
# 16               1985                                 740784     488236
# 17               1986                                 742986     488259
# 18               1987                                 740824     485443
# 19               1988                                 735260     480908
# 20               1989                                 728461     475016
# 21               1990                                 721609     469565
# 22               1991                                 718091     466517
# 23               1992                                 720494     467812
# 24               1993                                 731925     474483
# 25               1994                                 751900     487418
# 26               1995                                 779161     505452
# 27               1996                                 812028     528025
# 28               1997                                 849935     553613
# 29               1998                                 890400     581616
# 30               1999                                 931883     610642
# 31               2000                                 970933     638809
# 32               2001                                1006470     663903
# 33               2002                                1036452     686110
# 34               2003                                1061366     705185
# 35               2004                                1082218     722200
# 36               2005                                1101771     737151
# 37               2006                                1120859     752196
# 38               2007                                1141954     768431
# 39               2008                                1166539     787365
# 40               2009                                1197679     809282
# 41               2010                                1235164     835862
# 42               2011                                1280142     867308
# 43               2012                                1331585     903734
# 44               2013                                1389011     942675
# 45               2014                                1449216     984129
# 46               2015                                1510704    1026428
# 47               2016                                1564879    1062732
# 48               2017                                1624053    1102181
# 49               2018                                1681710    1143946
# 50        Grand Total                               44032484   29400807
#
#                   unnamed:_3 unnamed:_4                    unnamed:_5  \
# 0   Less than once per month       Once  One to three times per month
# 1                   48236757    8406335                      25755043
# 2                     459019     112440                        279100
# 3                     505472     124557                        307708
# 4                     546750     135055                        332798
# 5                     582891     143867                        354343
# 6                     614463     151071                        372660
# 7                     642322     156811                        388236
# 8                     667392     161238                        401661
# 9                     690485     164455                        413341
# 10                    712080     166470                        423512
# 11                    732432     167275                        432273
# 12                    751646     166936                        439765
# 13                    769498     165544                        445884
# 14                    785204     163171                        450355
# 15                    797192     159819                        452500
# 16                    804067     155563                        451832
# 17                    805678     150708                        448485
# 18                    802747     145685                        443103
# 19                    796553     140947                        436545
# 20                    788671     136853                        429772
# 21                    781293     133765                        423862
# 22                    777577     132146                        420500
# 23                    780827     132440                        421339
# 24                    793619     134932                        427725
# 25                    815983     139479                        439512
# 26                    846503     145652                        455790
# 27                    883551     152979                        475510
# 28                    925519     160995                        497721
# 29                    970830     169218                        521305
# 30                   1017206     177126                        544966
# 31                   1061363     184197                        566974
# 32                   1101135     190117                        586275
# 33                   1135208     194756                        602184
# 34                   1163833     198184                        614885
# 35                   1188397     200632                        625127
# 36                   1210805     202381                        633998
# 37                   1232973     203673                        642379
# 38                   1257186     204832                        651436
# 39                   1285685     206178                        662232
# 40                   1320440     207994                        675837
# 41                   1362659     210477                        692747
# 42                   1413084     213737                        713369
# 43                   1471017     217717                        737376
# 44                   1534673     222256                        764041
# 45                   1601834     227135                        792274
# 46                   1670361     232146                        821136
# 47                   1730083     239361                        849607
# 48                   1795041     247556                        881098
# 49                   1853510     255809                        909965
# 50                  48236757    8406335                      25755043
#
#      unnamed:_6
# 0   Grand Total
# 1     155831426
# 2       1558972
# 3       1716735
# 4       1855737
# 5       1976650
# 6       2081002
# 7       2171595
# 8       2251950
# 9       2324656
# 10      2390895
# 11      2451660
# 12      2507383
# 13      2557257
# 14      2599110
# 15      2628302
# 16      2640482
# 17      2636116
# 18      2617802
# 19      2590213
# 20      2558773
# 21      2530094
# 22      2514831
# 23      2522912
# 24      2562684
# 25      2634292
# 26      2732558
# 27      2852093
# 28      2987783
# 29      3133369
# 30      3281823
# 31      3422276
# 32      3547900
# 33      3654710
# 34      3743453
# 35      3818574
# 36      3886106
# 37      3952080
# 38      4023839
# 39      4107999
# 40      4211232
# 41      4336909
# 42      4487640
# 43      4661429
# 44      4852656
# 45      5054588
# 46      5260775
# 47      5446662
# 48      5649929
# 49      5844940
# 50    155831426

# %%
cannabis = cannabis.drop(['geo', 'dguid', 'uom', 'uom_id', 'scalar_factor', 'scalar_id', 'vector', 'status', 'symbol', 'terminated', 'decimals'], axis=1)
cannabis.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-a0a42a2df7a7> in <module>
# ----> 1 cannabis = cannabis.drop(['geo', 'dguid', 'uom', 'uom_id', 'scalar_factor', 'scalar_id', 'vector', 'status', 'symbol', 'terminated', 'decimals'], axis=1)
#       2 cannabis.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['geo' 'dguid' 'uom' 'uom_id' 'scalar_factor' 'scalar_id' 'vector'\n 'status' 'symbol' 'terminated' 'decimals'] not found in axis"

# %%
#Dataframe 

annual_age_consumption = cannabis.loc[(cannabis.frequency_of_use == 'Total, all frequencies')
                                      & (cannabis.prevalence == 'Consuming population of cannabis')
                                      & (cannabis.age_group != '15 years and over')
                                      & (cannabis.age_group != '65 years and over'),:]
annual_age_consumption = annual_age_consumption.reset_index(drop=True)
annual_age_consumption
# Out:
#      ref_date                        prevalence        age_group  \
# 0        1961  Consuming population of cannabis  15 to 17 years
# 1        1961  Consuming population of cannabis   18 to 24 years
# 2        1961  Consuming population of cannabis   25 to 44 years
# 3        1961  Consuming population of cannabis   45 to 64 years
# 4        1962  Consuming population of cannabis  15 to 17 years
# ..        ...                               ...              ...
# 227      2017  Consuming population of cannabis   45 to 64 years
# 228      2018  Consuming population of cannabis  15 to 17 years
# 229      2018  Consuming population of cannabis   18 to 24 years
# 230      2018  Consuming population of cannabis   25 to 44 years
# 231      2018  Consuming population of cannabis   45 to 64 years
#
#            frequency_of_use coordinate      value
# 0    Total, all frequencies    1.1.2.1    25976.0
# 1    Total, all frequencies    1.1.3.1   147670.0
# 2    Total, all frequencies    1.1.4.1    47466.0
# 3    Total, all frequencies    1.1.5.1    56399.0
# 4    Total, all frequencies    1.1.2.1    30871.0
# ..                      ...        ...        ...
# 227  Total, all frequencies    1.1.5.1  1138798.0
# 228  Total, all frequencies    1.1.2.1   305543.0
# 229  Total, all frequencies    1.1.3.1  1377621.0
# 230  Total, all frequencies    1.1.4.1  2171770.0
# 231  Total, all frequencies    1.1.5.1  1180015.0
#
# [232 rows x 6 columns]

# %%
print(list(annual_age_consumption.age_group.unique()))

teen_over_time = annual_age_consumption.loc[annual_age_consumption.age_group == '15 to 17 years ', :]
college_over_time = annual_age_consumption.loc[annual_age_consumption.age_group == '18 to 24 years', :]
yopro_over_time = annual_age_consumption.loc[annual_age_consumption.age_group == '25 to 44 years', :]
boomer_over_time = annual_age_consumption.loc[annual_age_consumption.age_group == '45 to 64 years', :]

one = [sum(x) for x in zip(list(teen_over_time.value), list(college_over_time.value))]
two = [sum(x) for x in zip(one, list(yopro_over_time.value))]
three = [sum(x) for x in zip(two, list(boomer_over_time.value))]

plt.scatter(teen_over_time.ref_date, np.divide(teen_over_time.value, three))
plt.scatter(college_over_time.ref_date, np.divide(college_over_time.value, three))
plt.scatter(yopro_over_time.ref_date, np.divide(yopro_over_time.value, three))
plt.scatter(boomer_over_time.ref_date, np.divide(boomer_over_time.value, three))
plt.legend(['15-17','18-24','25-44','45+'])
# Out:
# ['15 to 17 years ', '18 to 24 years', '25 to 44 years', '45 to 64 years']

# %%
#Cannabis Consumption per Population // Merge Cannabis and Population Dataset
gdp = pd.read_csv('Resources\Canada_GDP_1960-2018.csv')
gdp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1f509bbb3e4e> in <module>
#       1 #Cannabis Consumption per Population // Merge Cannabis and Population Dataset
# ----> 2 gdp = pd.read_csv('Resources\Canada_GDP_1960-2018.csv')
#       3 gdp
#
# NameError: name 'pd' is not defined

# %%
#Cannabis Consumption v. Economic Growth // Does Consumption Increase v. Econ Growth

# %%
gdp = pd.read_csv()
